# %%
import pandas as pd

# %%
a=pd.Series([1,2,3,4,5])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a=pd.Series([1,2,3,4.9,5])

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.9
# 4    5.0
# dtype: float64

# %%
a=pd.Series([1,2,3,'rash',5])

# %%
a
# Out:
# 0       1
# 1       2
# 2       3
# 3    rash
# 4       5
# dtype: object

# %%
a=pd.Series(['divya','rash','shaurya'])

# %%
a
# Out:
# 0      divya
# 1       rash
# 2    shaurya
# dtype: object

# %%
b = pd.DataFrame([[50,'sachin'],[55,'dravid'],[35,'kohli']],columns=['age','name'])

# %%
b
# Out:
#    age    name
# 0   50  sachin
# 1   55  dravid
# 2   35   kohli

# %%
df=pd.read_excel('C:\\Users\\dell\\Desktop\\DS lessons\\File Handling\\titanic3.xls')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.head(3)#top
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
# 2       1         0    Allison, Miss. Helen Loraine  female   2.0000      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
# 2      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
df.tail()#bottom
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.isnull()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
#df.dropna()#will delete the rows having null values. So, in this case a lot of data will be lost,

# %%
mean_df = df['age'].mean()

# %%
mean_df
# Out:
# 29.8811345124283

# %%
df['age']=df['age'].fillna(mean_df)

# %%
df.isnull()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False  False  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df['age']
# Out:
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
#           ...
# 1304    14.500000
# 1305    29.881135
# 1306    26.500000
# 1307    27.000000
# 1308    29.000000
# Name: age, Length: 1309, dtype: float64

# %%
df[['age','sex','pclass']]
# Out:
#             age     sex  pclass
# 0     29.000000  female       1
# 1      0.916700    male       1
# 2      2.000000  female       1
# 3     30.000000    male       1
# 4     25.000000  female       1
# ...         ...     ...     ...
# 1304  14.500000  female       3
# 1305  29.881135  female       3
# 1306  26.500000    male       3
# 1307  27.000000    male       3
# 1308  29.000000    male       3
#
# [1309 rows x 3 columns]

# %%
df[['age','pclass','survived']]
# Out:
#             age  pclass  survived
# 0     29.000000       1         1
# 1      0.916700       1         1
# 2      2.000000       1         0
# 3     30.000000       1         0
# 4     25.000000       1         0
# ...         ...     ...       ...
# 1304  14.500000       3         0
# 1305  29.881135       3         0
# 1306  26.500000       3         0
# 1307  27.000000       3         0
# 1308  29.000000       3         0
#
# [1309 rows x 3 columns]

# %%
df[df.index==34]
# Out:
#     pclass  survived                      name   sex   age  sibsp  parch  \
# 34       1         0  Borebank, Mr. John James  male  42.0      0      0
#
#     ticket   fare cabin embarked boat  body              home.dest
# 34  110489  26.55   D22        S  NaN   NaN  London / Winnipeg, MB

# %%
df[df.index.isin(range(3,7))]
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0   19952   26.5500      E12        S    3    NaN
# 6  63.0      1      0   13502   77.9583       D7        S   10    NaN
#
#                          home.dest
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY

# %%
df.iloc[[100,120,130]]
# Out:
#      pclass  survived                                          name     sex  \
# 100       1         1  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male
# 120       1         1                  Frauenthal, Mr. Isaac Gerald    male
# 130       1         1                Gibson, Miss. Dorothy Winifred  female
#
#       age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# 100  49.0      1      0  PC 17485  56.9292   A20        C    1   NaN
# 120  43.0      1      0     17765  27.7208   D40        C    5   NaN
# 130  22.0      0      1    112378  59.4000   NaN        C    7   NaN
#
#           home.dest
# 100  London / Paris
# 120    New York, NY
# 130    New York, NY

# %%
df.loc[3:7]
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0   19952   26.5500      E12        S    3    NaN
# 6  63.0      1      0   13502   77.9583       D7        S   10    NaN
# 7  39.0      0      0  112050    0.0000      A36        S  NaN    NaN
#
#                          home.dest
# 3  Montreal, PQ / Chesterville, ON
# ...

# %%
#querying

# %%
df.query('sex=="female"')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %% [markdown]
# df_1=df.query('age'>50 and 'sex=="female"')

# %%
df_1=df.query('(age>50) and (sex=="female")')

# %%
df_1
# Out:
#       pclass  survived                                               name  \
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 33         1         1                           Bonnell, Miss. Elizabeth
# 42         1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43         1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 48         1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 50         1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 78         1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 79         1         1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 95         1         1              Dodge, Mrs. Washington (Ruth Vidaver)
# ...

# %%
a=df_1.query('survived != 1')

# %%
a
# Out:
#      pclass  survived                                          name     sex  \
# 286       1         0        Straus, Mrs. Isidor (Rosalie Ida Blun)  female
# 456       2         0  Howard, Mrs. Benjamin (Ellen Truelove Arman)  female
# 490       2         0                             Mack, Mrs. (Mary)  female
#
#       age  sibsp  parch       ticket      fare    cabin embarked boat  body  \
# 286  63.0      1      0     PC 17483  221.7792  C55 C57        S  NaN   NaN
# 456  60.0      1      0        24065   26.0000      NaN        S  NaN   NaN
# 490  57.0      0      0  S.O./P.P. 3   10.5000      E77        S  NaN  52.0
#
#                       home.dest
# 286                New York, NY
# 456            Swindon, England
# 490  Southampton / New York, NY

# %%
df_1.to_excel('C:\\Users\\dell\\Desktop\\DS lessons\\File Handling\\filtered age.xlsx')

# %%
df.value_counts('sex')
# Out:
# sex
# male      843
# female    466
# dtype: int64

# %%
df.value_counts('survived')
# Out:
# survived
# 0    809
# 1    500
# dtype: int64

# %%
df.value_counts('sex').plot(kind= 'bar')
# Out:
# <Axes: xlabel='sex'>

# %%
df.value_counts('survived').plot(kind= 'bar')
# Out:
# <Axes: xlabel='survived'>

# %%
df.value_counts('pclass').plot(kind= 'bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
#groupby

# %%
df.groupby('sex').mean()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3900\3838006174.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('sex').mean()
#           pclass  survived        age     sibsp     parch       fare  \
# sex
# female  2.154506  0.727468  28.886935  0.652361  0.633047  46.198097
# male    2.372479  0.190985  30.430716  0.413998  0.247924  26.154601
#
#              body
# sex
# female  166.62500
# male    160.39823

# %%
df.groupby('pclass').mean()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3900\189473267.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('pclass').mean()
#         survived        age     sibsp     parch       fare        body
# pclass
# 1       0.619195  38.039569  0.436533  0.365325  87.508992  162.828571
# 2       0.429603  29.528333  0.393502  0.368231  21.179196  167.387097
# 3       0.255289  26.302223  0.568406  0.400564  13.302889  155.818182

# %%
df.groupby('sex').sum().plot(kind = 'bar')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3900\3099875137.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('sex').sum().plot(kind = 'bar')
# <Axes: xlabel='sex'>

# %%
df.groupby('sex').mean().plot(kind = 'bar')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3900\3745539982.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('sex').mean().plot(kind = 'bar')
# <Axes: xlabel='sex'>

# %%
df.groupby('pclass').mean().plot(kind = 'bar')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3900\1668782548.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('pclass').mean().plot(kind = 'bar')
# <Axes: xlabel='pclass'>

# %%
df.groupby('sex').sum().plot(kind = 'bar')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3900\3099875137.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('sex').sum().plot(kind = 'bar')
# <Axes: xlabel='sex'>

# %%
df.groupby(['sex','survived','pclass'])['survived'].sum()
# Out:
# sex     survived  pclass
# female  0         1           0
#                   2           0
#                   3           0
#         1         1         139
#                   2          94
#                   3         106
# male    0         1           0
#                   2           0
#                   3           0
#         1         1          61
#                   2          25
#                   3          75
# Name: survived, dtype: int64

# %%
import numpy as np

# %%
df.pivot_table('survived', index=['pclass','sex'], aggfunc={'survived': np.sum})
# Out:
#                survived
# pclass sex
# 1      female       139
#        male          61
# 2      female        94
#        male          25
# 3      female       106
#        male          75
